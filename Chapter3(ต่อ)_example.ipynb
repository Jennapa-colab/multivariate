# %% [markdown]
# <a href="https://colab.research.google.com/github/Jennapa-colab/multivariate/blob/main/Chapter3(%E0%B8%95%E0%B9%88%E0%B8%AD)_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv('nndb_flat.csv')
data.head(10)
# Out:
#      ID               FoodGroup  ... Selenium_USRDA Zinc_USRDA
# 0  1001  Dairy and Egg Products  ...       0.018182   0.008182
# 1  1002  Dairy and Egg Products  ...       0.018182   0.004545
# 2  1003  Dairy and Egg Products  ...       0.000000   0.000909
# 3  1004  Dairy and Egg Products  ...       0.263636   0.241818
# 4  1005  Dairy and Egg Products  ...       0.263636   0.236364
# 5  1006  Dairy and Egg Products  ...       0.263636   0.216364
# 6  1007  Dairy and Egg Products  ...       0.263636   0.216364
# 7  1008  Dairy and Egg Products  ...       0.263636   0.267273
# 8  1009  Dairy and Egg Products  ...       0.514545   0.311818
# 9  1010  Dairy and Egg Products  ...       0.263636   0.253636
#
# [10 rows x 45 columns]

# %%
data.shape
# Out:
# (6908, 45)

# %%
pd.plotting.scatter_matrix(data)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f68659f2750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f68659cfc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6865995310>,
#         ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f68651d26d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6865187c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6865147210>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f68650fe790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f68650b2d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f68650752d0>,
#         ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6864905850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f68648baed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f686487c590>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f6864832c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f68647f42d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f68647a8950>,
#         ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6864058a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6864004b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6863fcf590>],
#        ...,
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f6851d9e710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6851dd4c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6851d95250>,
#         ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f68515b2fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f68515705d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6851528b50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f68514ea110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f685149f690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f68514d4c10>,
#         ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6850cfca10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6850cb2f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6850c72550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f6850c28ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6850c55b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f685870ea10>,
#         ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6850445410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f68503f9990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f68503aff10>]],
#       dtype=object)

# %% [markdown]
# เนื่องจาก Data มี dimention มากเกินไป เราจะทดสอบดูว่า column ใด ให้ข้อมูลซ้ำกับ column อื่น แล้วลบมันออก

# %%
newdata = data.iloc[:,7:]
newdata.head()
# Out:
#    Energy_kcal  Protein_g  Fat_g  ...  Phosphorus_USRDA  Selenium_USRDA  Zinc_USRDA
# 0        717.0       0.85  81.11  ...          0.034286        0.018182    0.008182
# 1        717.0       0.85  81.11  ...          0.032857        0.018182    0.004545
# 2        876.0       0.28  99.48  ...          0.004286        0.000000    0.000909
# 3        353.0      21.40  28.74  ...          0.552857        0.263636    0.241818
# 4        371.0      23.24  29.68  ...          0.644286        0.263636    0.236364
#
# [5 rows x 38 columns]

# %% [markdown]
# ตรวจสอบว่า ระหว่าง columns มี correlation กันมากน้อยแค่ไหน ด้วย numpy

# %%
import numpy as np

# %%
corr = np.corrcoef(newdata.to_numpy().T)

# %%
corr
# Out:
# array([[1.        , 0.16295448, 0.81068711, ...,        nan,        nan,
#                nan],
#        [0.16295448, 1.        , 0.07879508, ...,        nan,        nan,
#                nan],
#        [0.81068711, 0.07879508, 1.        , ...,        nan,        nan,
#                nan],
#        ...,
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan]])

# %%
for i in range(corr.shape[0]): 
   for j in range(corr.shape[1]):
      if (i !=j) and (corr[i,j] == 1.):
        print(f'row = {i} column = {j} corrcoef = {corr[i,j]}')

# %%
newdata.iloc[:5,11:29]
# Out:
#    Folate_mcg  Niacin_mg  Riboflavin_mg  ...  VitC_USRDA  VitE_USRDA  Folate_USRDA
# 0         3.0      0.042          0.034  ...         0.0    0.154667        0.0075
# 1         3.0      0.042          0.034  ...         0.0    0.154667        0.0075
# 2         0.0      0.003          0.005  ...         0.0    0.186667        0.0000
# 3        36.0      1.016          0.382  ...         0.0    0.016667        0.0900
# 4        20.0      0.118          0.351  ...         0.0    0.017333        0.0500
#
# [5 rows x 18 columns]

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(newdata.iloc[:,11],newdata.iloc[:,28])

# %%
plt.plot(newdata.iloc[:,11],newdata.iloc[:,28],'r.')

# %% [markdown]
# *DATA ที่มี correlation เป็นค่าอื่นๆ*

# %%
plt.plot(newdata.iloc[:,11],newdata.iloc[:,29],'r.')
